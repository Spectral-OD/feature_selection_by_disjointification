# %% [markdown]
# # Disjointification Model Validation
# - Check the performance on the model based on the correclation threshold
# - Check the performance of features identified as better vs. worse by Disjointification
# - Check the performance when selecting more features

# %% [markdown]
# ## Defs / Imports

# %%
import disjointification
from pathlib import Path
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science', 'notebook'])

# %% [markdown]
# ## Load Saved Model

# %%
# PBSr Classification
save_point = Path(r"disjointification_model_point_bi_serial_fulldataset\09_09_2023__00_53_51") # savepoint with correlation threshold 0.8
save_point = Path(r"disjointification_model_point_bi_serial_fulldataset\09_09_2023__01_24_48\09_09_2023__01_24_48.pkl") # savepoint with correlation threshold 0.4
save_point = Path(r"disjointification_model_point_bi_serial_fulldataset\09_09_2023__03_44_12\09_09_2023__03_44_12.pkl") # savepoint with  correlation threshold 0.2

# # Kendall classification
# # save_point = Path(r"\model\06_24_2023__18_27_55\06_24_2023__18_27_55.pkl") # savepoint with 500 features, no classification
# # save_point = Path(r"model\07_09_2023__21_36_14.pkl") # savepoint with 2500 features, no classification
# # save_point = Path(r"\model\08_08_2023__10_03_00\08_08_2023__10_03_00.pkl") # savepoint with full dataset and correlation threshold 0.7
# save_point = Path(r"\model\08_08_2023__14_15_26\08_08_2023__14_15_26.pkl") # savepoint with full dataset and correlation threshold 0.4
# # save_point = Path(r"\model\08_08_2023__20_07_47\08_08_2023__20_07_47.pkl") # savepoint with full dataset and correlation threshold 0.2

# PBSr Classification - partial dataset
# save_point = Path(r"disjointification_model_point_bi_serial_20p_instances\09_08_2023__18_10_09\09_08_2023__18_10_09.pkl") # savepoint with 20% instances and correlation threshold 0.8
# save_point = Path(r"disjointification_model_point_bi_serial_20p_instances\09_08_2023__18_14_23\09_08_2023__18_14_23.pkl") # savepoint with 20% instances and correlation threshold 0.4
# save_point = Path(r"disjointification_model_point_bi_serial_20p_instances\09_08_2023__18_46_09\09_08_2023__18_46_09.pkl") # savepoint with 20% instances and correlation threshold 0.2


disjointification_model = disjointification.from_file(save_point)
disjointification_model.describe()
disjointification_model.features_df.head()
# Out:
# Disjointification Test Description
# features data: (3069, 9259)
# labels data: (3069, 2)
# regression label: Lympho
# classification label: ER
# correlation method regression: pearson
# correlation method regression: <function point_bi_serial_r_correlation at 0x00000151E6E9A830>
# min num of features to keep in disjointification: 200
# correlation threshold: 0.2
# last save point: \model\09_09_2023__03_44_12\09_09_2023__03_44_12.pkl
# number of features kept in disjointification: lin 200, log 200
#                  A2M     A4GNT      AAAS      AACS     AADAC      AAK1  \
# samplename
# F1         -1.098234 -0.615048 -1.670827 -0.539020  0.098325 -1.989513
# F2          0.110096 -0.615048  0.248934  0.032084  0.262344 -1.211690
# F3         -1.779393 -0.615048 -0.422635  0.392158 -0.711190 -0.210792
# F4          0.268360 -0.615048  0.236302  0.563540 -0.373168 -0.839605
# F5          0.616851 -0.615048 -0.988261 -0.083663  0.067739 -0.732227
#
# ...

# %%
# PBSr Correlation
validations  = [(Path(r"disjointification_model_point_bi_serial_20p_instances\09_08_2023__18_10_09\09_08_2023__18_10_09.pkl"), "savepoint with 20% instances and correlation threshold 0.8"),
               (Path(r"disjointification_model_point_bi_serial_20p_instances\09_08_2023__18_14_23\09_08_2023__18_14_23.pkl"), "savepoint with 20% instances and correlation threshold 0.4"),
               (Path(r"disjointification_model_point_bi_serial_20p_instances\09_08_2023__18_46_09\09_08_2023__18_46_09.pkl"), "savepoint with 20% instances and correlation threshold 0.2"),]

# # Kendall Correlation
# validations  = [(Path(r"\model\08_08_2023__10_03_00\08_08_2023__10_03_00.pkl"), "savepoint with full dataset and correlation threshold 0.7"),
#                (Path(r"\model\08_08_2023__14_15_26\08_08_2023__14_15_26.pkl"), "savepoint with full dataset and correlation threshold 0.4"),
#                (Path(r"\model\08_08_2023__20_07_47\08_08_2023__20_07_47.pkl"), "savepoint with full dataset and correlation threshold 0.2")]

for save_point_path, short_description in validations:
    print("\n\n\n")
    disjointification.validation_visualize_01(save_point_path, short_description,stop_num_features=200, ylim=[0.8,1.0])
    print("\n\n\n")
# Out:
# Validation Visualize: savepoint with 20% instances and correlation threshold 0.8
# Disjointification Test Description
# features data: (613, 9259)
# labels data: (613, 2)
# regression label: Lympho
# classification label: ER
# correlation method regression: pearson
# correlation method regression: <function point_bi_serial_r_correlation at 0x00000151E6E9A830>
# min num of features to keep in disjointification: 200
# correlation threshold: 0.8
# last save point: \model\09_08_2023__18_10_09\09_08_2023__18_10_09.pkl
# number of features kept in disjointification: lin 200, log 200
# Best features vs. Worst Features - Regression/Classification Score
# Validation Visualize: savepoint with 20% instances and correlation threshold 0.4
# Disjointification Test Description
# features data: (613, 9259)
# labels data: (613, 2)
# regression label: Lympho
# classification label: ER
# correlation method regression: pearson
# ...

# %% [markdown]
# ## Schedule
# - The goal for July is to meet up once a week
# - I will be on Miluim for the next three weeks so I will try and propose times which might work
# - By end of July, the code should be done
# - By Aug. 16th, the report should be submitted (Ben will be able to give us an example for a project summary)
#
# ## Following tasks:
# - Use a wrapper on validation set - once Disjointification is used to reduce to 500 features, select best N features by train/test/validation split
# - Benchmark with RF feature selection
# - Benchmark with a genetic algorithm
